# %%
import cv2 
from matplotlib import pyplot as plt
from PIL import Image
import pickle
import shutil
import os
import glob
import csv
import numpy as np
from collections import OrderedDict

# %%
pickle_file1 = open('/media/osero/SamsungSSD/pickles_yedek_unsorted/features_right_hand_frames_325.pickle', 'rb') ## 9564
features1,labels1 = pickle.load(pickle_file1)

pickle_file2 = open('/media/osero/SamsungSSD/pickles_yedek_unsorted/features_right_hand_frames_large_325_to_.pickle', 'rb')
features2,labels2 = pickle.load(pickle_file2)

cc = 5

# %%
new_list_feature = []
new_list_label = []
new_list_feature.extend(features1[0:9564])
new_list_label.extend(labels1[0:9564])
new_list_feature.extend(features2)
new_list_label.extend(labels2)
print(len(new_list_feature))
print(len(new_list_label))

with open('/media/osero/SamsungSSD/pickles/features_right_hand_frames_large.pickle', 'wb') as handle:
    pickle.dump((new_list_feature, new_list_label), handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 22542
# 22542

# %%
pickle_file11 = open('/media/osero/SamsungSSD/pickles/features_right_hand_frames_small_ordered.pickle', 'rb')
paths11, features11,labels11 = pickle.load(pickle_file11)
print(len(labels11))
cc = 5
cc = 4
# Out:
# 22542
